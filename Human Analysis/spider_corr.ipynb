# %% [markdown]
# # Reference
# https://www.kaggle.com/code/fabiendaniel/food-feed-facts

# %%
import pandas as pd

# %%
# This is the samll.csv data
df = pd.read_csv('https://raw.githubusercontent.com/anrath/BigDataProject/master/data/small.csv?token=GHSAT0AAAAAACP3XZ64K7TX4LWYJPP6NT34ZQNWB4Q', delimiter='\t')
# Out:
# /var/folders/x_/qkfj00656_qg6nsj5fclf5sc0000gn/T/ipykernel_8535/3414238328.py:1: DtypeWarning: Columns (67) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://raw.githubusercontent.com/anrath/BigDataProject/master/data/small.csv?token=GHSAT0AAAAAACP3XZ64K7TX4LWYJPP6NT34ZQNWB4Q', delimiter='\t')

# %%
df
# Out:
#                 code                                                url  \
# 0      3596710517510  http://world-en.openfoodfacts.org/product/3596...
# 1      3596710517527  http://world-en.openfoodfacts.org/product/3596...
# 2      3596710517534  http://world-en.openfoodfacts.org/product/3596...
# 3      3596710517640  http://world-en.openfoodfacts.org/product/3596...
# 4      3596710517657  http://world-en.openfoodfacts.org/product/3596...
# ...              ...                                                ...
# 19994  3665020370082  http://world-en.openfoodfacts.org/product/3665...
# 19995  3665020370099  http://world-en.openfoodfacts.org/product/3665...
# 19996  3665030330069  http://world-en.openfoodfacts.org/product/3665...
# 19997  3665030330076  http://world-en.openfoodfacts.org/product/3665...
# 19998  3665030330144  http://world-en.openfoodfacts.org/product/3665...
#
#             creator   created_t      created_datetime  last_modified_t  \
# 0           kiliweb  1682951305  2023-05-01T14:28:25Z       1709956237
# 1           kiliweb  1672054652  2022-12-26T11:37:32Z       1708232344
# 2           kiliweb  1682936768  2023-05-01T10:26:08Z       1708148079
# 3      smoothie-app  1686043401  2023-06-06T09:23:21Z       1708103678
# 4           kiliweb  1680188892  2023-03-30T15:08:12Z       1708147290
# ...             ...         ...                   ...              ...
# 19994       kiliweb  1556345803  2019-04-27T06:16:43Z       1556345805
# 19995       kiliweb  1525099013  2018-04-30T14:36:53Z       1578496432
# 19996       kiliweb  1554890624  2019-04-10T10:03:44Z       1554896781
# 19997       kiliweb  1570471709  2019-10-07T18:08:29Z       1671535226
# 19998       kiliweb  1549565189  2019-02-07T18:46:29Z       1612458838
#
#       last_modified_datetime last_modified_by  last_updated_t  \
# 0       2024-03-09T03:50:37Z  org-auchan-apaw    1.709956e+09
# 1       2024-02-18T04:59:04Z  org-auchan-apaw    1.708232e+09
# 2       2024-02-17T05:34:39Z  org-auchan-apaw    1.708148e+09
# 3       2024-02-16T17:14:38Z  org-auchan-apaw    1.708104e+09
# 4       2024-02-17T05:21:30Z  org-auchan-apaw    1.708147e+09
# ...                      ...              ...             ...
# 19994   2019-04-27T06:16:45Z              NaN    1.707619e+09
# 19995   2020-01-08T15:13:52Z        computman    1.707563e+09
# 19996   2019-04-10T11:46:21Z      moon-rabbit    1.707618e+09
# 19997   2022-12-20T11:20:26Z       roboto-app    1.707633e+09
# 19998   2021-02-04T17:13:58Z       roboto-app    1.707613e+09
#
#       last_updated_datetime  ... glycemic-index_100g water-hardness_100g  \
# 0      2024-03-09T03:50:37Z  ...                 NaN                 NaN
# 1      2024-02-18T04:59:04Z  ...                 NaN                 NaN
# 2      2024-02-17T05:34:39Z  ...                 NaN                 NaN
# 3      2024-02-16T17:14:38Z  ...                 NaN                 NaN
# 4      2024-02-17T05:21:30Z  ...                 NaN                 NaN
# ...                     ...  ...                 ...                 ...
# 19994  2024-02-11T02:38:01Z  ...                 NaN                 NaN
# 19995  2024-02-10T10:55:05Z  ...                 NaN                 NaN
# 19996  2024-02-11T02:15:30Z  ...                 NaN                 NaN
# 19997  2024-02-11T06:26:51Z  ...                 NaN                 NaN
# 19998  2024-02-11T00:49:55Z  ...                 NaN                 NaN
#
#       choline_100g phylloquinone_100g beta-glucan_100g inositol_100g  \
# 0              NaN                NaN              NaN           NaN
# 1              NaN                NaN              NaN           NaN
# 2              NaN                NaN              NaN           NaN
# 3              NaN                NaN              NaN           NaN
# 4              NaN                NaN              NaN           NaN
# ...            ...                ...              ...           ...
# 19994          NaN                NaN              NaN           NaN
# 19995          NaN                NaN              NaN           NaN
# 19996          NaN                NaN              NaN           NaN
# 19997          NaN                NaN              NaN           NaN
# 19998          NaN                NaN              NaN           NaN
#
#       carnitine_100g sulphate_100g nitrate_100g acidity_100g
# 0                NaN           NaN          NaN          NaN
# 1                NaN           NaN          NaN          NaN
# 2                NaN           NaN          NaN          NaN
# 3                NaN           NaN          NaN          NaN
# 4                NaN           NaN          NaN          NaN
# ...              ...           ...          ...          ...
# 19994            NaN           NaN          NaN          NaN
# 19995            NaN           NaN          NaN          NaN
# 19996            NaN           NaN          NaN          NaN
# 19997            NaN           NaN          NaN          NaN
# 19998            NaN           NaN          NaN          NaN
#
# [19999 rows x 206 columns]

# %%
score_columns = ["ecoscore_score", "ecoscore_grade", "nutrient_levels_tags", "product_quantity", "owner", "main_category", "main_category_en", "carbon-footprint_100g", "carbon-footprint-from-meat-or-fish_100g", "nutrition-score-fr_100g", "nutrition-score-uk_100g", "glycemic-index_100g", "water-hardness_100g"]
more_score_columns = ["nutriscore_score", "nutriscore_grade", "nova_group", "pnns_groups_1", "pnns_groups_2", "food_groups", "food_groups_tags", "food_groups_en", "states", "states_tags", "states_en", "brand_owner",]

nutrient_columns = ["energy-kj_100g", "energy-kcal_100g", "energy_100g", "energy-from-fat_100g", "fat_100g", "saturated-fat_100g", "butyric-acid_100g", "caproic-acid_100g", "caprylic-acid_100g", "capric-acid_100g", "lauric-acid_100g", "myristic-acid_100g", "palmitic-acid_100g", "stearic-acid_100g", "arachidic-acid_100g", "behenic-acid_100g", "lignoceric-acid_100g", "cerotic-acid_100g", "montanic-acid_100g", "melissic-acid_100g", "unsaturated-fat_100g", "monounsaturated-fat_100g", "omega-9-fat_100g", "polyunsaturated-fat_100g", "omega-3-fat_100g", "omega-6-fat_100g", "alpha-linolenic-acid_100g", "eicosapentaenoic-acid_100g", "docosahexaenoic-acid_100g", "linoleic-acid_100g", "arachidonic-acid_100g", "gamma-linolenic-acid_100g", "dihomo-gamma-linolenic-acid_100g", "oleic-acid_100g", "elaidic-acid_100g", "gondoic-acid_100g", "mead-acid_100g", "erucic-acid_100g", "nervonic-acid_100g", "trans-fat_100g", "cholesterol_100g", "carbohydrates_100g", "sugars_100g", "added-sugars_100g", "sucrose_100g", "glucose_100g", "fructose_100g", "lactose_100g", "maltose_100g", "maltodextrins_100g", "starch_100g", "polyols_100g", "erythritol_100g", "fiber_100g", "soluble-fiber_100g", "insoluble-fiber_100g", "proteins_100g", "casein_100g", "serum-proteins_100g", "nucleotides_100g", "salt_100g", "added-salt_100g", "sodium_100g", "alcohol_100g", "vitamin-a_100g", "beta-carotene_100g", "vitamin-d_100g", "vitamin-e_100g", "vitamin-k_100g", "vitamin-c_100g", "vitamin-b1_100g", "vitamin-b2_100g", "vitamin-pp_100g", "vitamin-b6_100g", "vitamin-b9_100g", "folates_100g", "vitamin-b12_100g", "biotin_100g", "pantothenic-acid_100g", "silica_100g", "bicarbonate_100g", "potassium_100g", "chloride_100g", "calcium_100g", "phosphorus_100g", "iron_100g", "magnesium_100g", "zinc_100g", "copper_100g", "manganese_100g", "fluoride_100g", "selenium_100g", "chromium_100g", "molybdenum_100g", "iodine_100g", "caffeine_100g", "taurine_100g", "ph_100g", "fruits-vegetables-nuts_100g", "fruits-vegetables-nuts-dried_100g", "fruits-vegetables-nuts-estimate_100g", "fruits-vegetables-nuts-estimate-from-ingredients_100g", "collagen-meat-protein-ratio_100g", "cocoa_100g", "chlorophyl_100g", "choline_100g", "phylloquinone_100g", "beta-glucan_100g", "inositol_100g", "carnitine_100g", "sulphate_100g", "nitrate_100g", "acidity_100g"]
metadata_columns = ["image_url", "image_small_url", "image_ingredients_url", "image_ingredients_small_url", "image_nutrition_url", "image_nutrition_small_url"]
more_columns = ["code", "url", "creator", "created_t", "created_datetime", "last_modified_t", "last_modified_datetime", "last_modified_by", "last_updated_t", "last_updated_datetime", "data_quality_errors_tags", "unique_scans_n", "popularity_tags", "completeness", "last_image_t", "last_image_datetime",]
gen_columns = ["product_name", "abbreviated_product_name", "generic_name", "quantity", "packaging", "packaging_tags", "packaging_en", "packaging_text", "brands", "brands_tags", "categories", "categories_tags", "categories_en", "origins", "origins_tags", "origins_en", "manufacturing_places", "manufacturing_places_tags", "labels", "labels_tags", "labels_en", "emb_codes", "emb_codes_tags", "first_packaging_code_geo", "cities", "cities_tags", "purchase_places", "stores", "countries", "countries_tags", "countries_en", ]

ingredient = ["ingredients_text", "ingredients_tags", "ingredients_analysis_tags", "allergens", "allergens_en", "traces", "traces_tags", "traces_en", "serving_size", "serving_quantity", "no_nutrition_data", "additives_n", "additives", "additives_tags", "additives_en", ]

# %%
new_cols = ['sodium_100g', "fat_100g", "saturated-fat_100g","sugars_100g", "carbohydrates_100g", "proteins_100g"]
subset_gen_columns = ['product_name', 'countries_en', 'brands', 'abbreviated_product_name', 'generic_name', 'quantity', 'countries_en']
subset_scores_columns = ['ecoscore_score', 'ecoscore_grade', 'nutrient_levels_tags', 'main_category_en', 'nutriscore_score', 'nutriscore_grade', 'nova_group', 'food_groups_en']+ new_cols
columns = ['code'] + subset_gen_columns + subset_scores_columns
columns
# Out:
# ['code',
#  'product_name',
#  'countries_en',
#  'brands',
#  'abbreviated_product_name',
#  'generic_name',
#  'quantity',
#  'countries_en',
#  'ecoscore_score',
#  'ecoscore_grade',
#  'nutrient_levels_tags',
#  'main_category_en',
#  'nutriscore_score',
#  'nutriscore_grade',
#  'nova_group',
#  'food_groups_en',
#  'sodium_100g',
#  'fat_100g',
#  'saturated-fat_100g',
#  'sugars_100g',
#  'carbohydrates_100g',
#  'proteins_100g']

# %%
df= df[columns]
df.head()
# Out:
#             code                                     product_name  \
# 0  3596710517510                     Choco Stick chocolat au lait
# 1  3596710517527           Fromage à tartiner ail et fines herbes
# 2  3596710517534  AUCHAN Noir praliné et éclats de nougatine 150g
# 3  3596710517640                 Epinards en branches en portions
# 4  3596710517657                         AUCHAN Lait façon rocher
#
#    countries_en                  brands             abbreviated_product_name  \
# 0  France,World                  Auchan  Auchan choco stick chocolat lait 15
# 1  France,World                   Pouce  Pouce fromage a tartiner ail et fin
# 2  France,World  Auchan, Auchan Gourmet  Auchan gourmet choco nr praline pep
# 3  France,World                  Auchan  Auchan epinards branches en portion
# 4  France,World                  Auchan  Auchan gou chocolat lait facon roch
#
#                                         generic_name  quantity  countries_en  \
# 0  Bâtonnets de biscuits enrobés de chocolat au lait  0.115 kg  France,World
# 1     Fromage à tartiner à l'ail et aux fines herbes   0.15 kg  France,World
# 2  Chocolat noir fourrage (48%) au praliné et aux...   0.15 kg  France,World
# 3        Epinards en branches, en portions, surgelés      1 kg  France,World
# 4  Chocolat supérieur au lait (52%) fourrage au p...   0.15 kg  France,World
#
#    ecoscore_score ecoscore_grade  ... nutriscore_score nutriscore_grade  \
# 0            34.0              d  ...             22.0                e
# 1             NaN        unknown  ...              NaN          unknown
# 2            15.0              e  ...             21.0                e
# 3             NaN        unknown  ...              NaN          unknown
# 4            18.0              e  ...             24.0                e
#
#    nova_group                    food_groups_en  sodium_100g fat_100g  \
# 0         4.0  Sugary snacks,Biscuits and cakes        0.092     27.0
# 1         NaN                               NaN        0.520     25.0
# 2         4.0  Sugary snacks,Chocolate products        0.024     33.0
# 3         NaN                               NaN        0.020      0.5
# 4         4.0  Sugary snacks,Chocolate products        0.064     33.0
#
#    saturated-fat_100g  sugars_100g  carbohydrates_100g  proteins_100g
# 0                15.0         36.0                62.0            6.3
# 1                17.0          3.5                 3.5            6.0
# 2                16.0         49.0                51.0            7.0
# 3                 0.1          0.5                 0.6            2.8
# 4                16.0         52.0                54.0            8.2
#
# [5 rows x 22 columns]

# %%
df = df.dropna(subset=["sodium_100g", 'fat_100g','saturated-fat_100g','sugars_100g','carbohydrates_100g','proteins_100g']).reset_index()

# %%
df.iloc[df.ecoscore_score.sort_values(ascending= False).index[0]]
# Out:
# index                                                                   13182
# code                                                            3661218260043
# product_name                                                    Pommes Ariane
# countries_en                                                           France
# brands                                                         Les naturianes
# abbreviated_product_name                                                  NaN
# generic_name                                                              NaN
# quantity                                                   6 fruits 115/135 g
# countries_en                                                           France
# ecoscore_score                                                          123.0
# ecoscore_grade                                                              a
# nutrient_levels_tags        en:fat-in-low-quantity,en:saturated-fat-in-low...
# main_category_en                                                       Apples
# nutriscore_score                                                         -3.0
# nutriscore_grade                                                            a
# nova_group                                                                NaN
# food_groups_en                                   Fruits and vegetables,Fruits
# sodium_100g                                                              0.04
# fat_100g                                                                  0.2
# saturated-fat_100g                                                        0.0
# sugars_100g                                                              10.0
# carbohydrates_100g                                                       14.0
# proteins_100g                                                             0.3
# Name: 8707, dtype: object

# %%
df.nutriscore_score.sort_values(ascending= False).index[:3]
# Out:
# Index([10908, 5279, 11392], dtype='int64')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Unhealthy foods

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have selected_rows, columns_to_graph, and num_features defined

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

colors = ['blue', 'green', 'red']  # Choose your colors for each graph
selected_rows = df.iloc[df.nutriscore_score.sort_values(ascending= False).index[:3]]
columns_to_graph = ["sodium_100g", 'fat_100g','saturated-fat_100g','sugars_100g','carbohydrates_100g','proteins_100g']
num_features = len(columns_to_graph)


for index, row in selected_rows.reset_index().iterrows():

    product_name = row['product_name']
    values = row[columns_to_graph].values
    angles = np.linspace(0, 2 * np.pi, num_features, endpoint=False).tolist()
    ax.fill(angles, values, color=colors[index], alpha=0.25)
    ax.plot(angles, values, color=colors[index], linewidth=2, label=product_name)

ax.set_yticklabels([])
ax.set_xticks(angles)
ax.set_xticklabels(columns_to_graph)
ax.legend()  # Add legend to distinguish different products

plt.show()

# %%
selected_rows = df.iloc[df.nutriscore_score.sort_values(ascending= False).index[:3]]
columns_to_graph = ["sodium_100g", 'fat_100g','saturated-fat_100g','sugars_100g','carbohydrates_100g','proteins_100g']

# Extract features
num_features = len(columns_to_graph)

# Create radar charts for each product
for index, row in selected_rows.iterrows():
    product_name = row['product_name']
    values = row[columns_to_graph].values
    angles = np.linspace(0, 2 * np.pi, num_features, endpoint=False).tolist()

    fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
    ax.fill(angles, values, color='blue', alpha=0.25)
    ax.plot(angles, values, color='blue', linewidth=2)
    ax.set_yticklabels([])
    ax.set_xticks(angles)
    ax.set_xticklabels(columns_to_graph)
    ax.set_title(product_name)

plt.show()

# %% [markdown]
# # Non-eco Friendly foods

# %%
selected_rows = df.iloc[df.ecoscore_score.sort_values(ascending= True).index[[1,3,5]]]
columns_to_graph = ["sodium_100g", 'fat_100g','saturated-fat_100g','sugars_100g','carbohydrates_100g','proteins_100g']

# Extract features
num_features = len(columns_to_graph)

# Create radar charts for each product
for index, row in selected_rows.iterrows():
    product_name = row['product_name']
    values = row[columns_to_graph].values
    angles = np.linspace(0, 2 * np.pi, num_features, endpoint=False).tolist()

    fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
    ax.fill(angles, values, color='blue', alpha=0.25)
    ax.plot(angles, values, color='blue', linewidth=2)
    ax.set_yticklabels([])
    ax.set_xticks(angles)
    ax.set_xticklabels(columns_to_graph)
    ax.set_title(product_name)

plt.show()

# %% [markdown]
# # correlation plot

# %%
import seaborn as sns

# %%
columns = ["sodium_100g", 'fat_100g','saturated-fat_100g','sugars_100g','carbohydrates_100g','proteins_100g', 'ecoscore_score', 'nutriscore_score']
data = df[columns]

# %%
correlation_matrix = data.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Plot')
plt.show()
