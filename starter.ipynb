# %%
import pandas as pd

# %%
df = pd.read_csv('data/openfoodfacts_export_35addedSugar.csv', delimiter='\t')
df.head()
# Out:
#             code  lc                               product_name_cs  \
# 0  4056489156192  fr  Hořká čokoláda s pekanovými ořechy a kokosem
# 1    79200558338  en                                           NaN
# 2    40000001607  en                                           NaN
# 3   853522000306  en                                           NaN
# 4    13409451328  en                                           NaN
#
#                               product_name_de  \
# 0  Way To Go Zartbitterschokolade Pecan Kokos
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                     product_name_en product_name_es          product_name_fr  \
# 0  Coconut Pecan Dark Chocolate Bar             NaN  Way to go Pecan Coconut
# 1             Nerds Candy - Rainbow             NaN                      NaN
# ...

# %%
# with open('data/columns.txt', 'w') as f:
#     for column in df.columns.tolist():
#         f.write('"' + column + '", ')

# %%
df[["code", "product_name_en", "generic_name_en", "quantity", "serving_size"]]
# Out:
#               code                       product_name_en  \
# 0    4056489156192      Coconut Pecan Dark Chocolate Bar
# 1      79200558338                 Nerds Candy - Rainbow
# 2      40000001607                     Original Skittles
# 3     853522000306                 Semi-Sweet Mini Chips
# 4      13409451328             Barbecue Sauce (Original)
# ..             ...                                   ...
# 386    70199051145            Caramel Macchiato Bon Bons
# 387    49646902248                 Caramel Apple Popcorn
# 388    37466017532             Milk Chocolate Golf Balls
# 389   845777018366      Knotty Grahams - Peppermint Bark
# 390   845777018038  Peppermint Mocha Dark Chocolate Bark
#
#           generic_name_en           quantity   serving_size
# 0                     NaN              180 g           30 g
# 1                     NaN            141.7 g            15g
# 2                     NaN            2.17 oz         61.5 g
# ...

# %%
df[["packaging", "packaging_tags", "brands", "brands_tags", "brand_owner", "categories", "categories_tags", "labels", "labels_tags", "countries", "countries_tags", "stores", "stores_tags"]]
# Out:
#              packaging          packaging_tags  \
# 0          Papier, Fsc         en:paper,fr:fsc
# 1    Box, Card-unknown  en:box,en:card-unknown
# 2                  NaN                     NaN
# 3                  NaN                     NaN
# 4           Pet-bottle           en:pet-bottle
# ..                 ...                     ...
# 386                NaN                     NaN
# 387                NaN                     NaN
# 388                NaN                     NaN
# 389                NaN                     NaN
# 390                NaN                     NaN
#
#                                         brands  \
# 0                     Fin Carré,Way to Go,Lidl
# 1                                 Nestlé,Nerds
# 2                                     Skittles
# 3    Enjoy Life,Enjoy Life Natural Brands  Llc
# 4                             Sweet Baby Ray's
# ..                                         ...
# 386                                     Scotts
# ...

# %% [markdown]
# It seems `manufacturing_places` and `origins` is empty for most rows so we probably can't run analyses on it.

# %%
df[["obsolete", "obsolete_since_date", "origins", "origins_tags", "origin_en", "manufacturing_places", "manufacturing_places_tags", "emb_codes", "emb_codes_tags"]]
# Out:
#      obsolete  obsolete_since_date origins origins_tags origin_en  \
# 0           0                  NaN   Ghana     en:ghana       NaN
# 1           0                  NaN     NaN          NaN       NaN
# 2           0                  NaN     NaN          NaN       NaN
# 3           0                  NaN     NaN          NaN       NaN
# 4           0                  NaN     NaN          NaN       NaN
# ..        ...                  ...     ...          ...       ...
# 386         0                  NaN     NaN          NaN       NaN
# 387         0                  NaN     NaN          NaN       NaN
# 388         0                  NaN     NaN          NaN       NaN
# 389         0                  NaN     NaN          NaN       NaN
# 390         0                  NaN     NaN          NaN       NaN
#
#     manufacturing_places manufacturing_places_tags emb_codes emb_codes_tags
# 0                Germany                   germany       NaN            NaN
# ...

# %%
df[["ingredients_text_en", "allergens", "allergens_tags", "traces", "traces_tags", "no_nutrition_data", "nutrition_data_per", "nutrition_data_prepared_per"]]
# Out:
#                                    ingredients_text_en
# 0    SUGAR, CHOCOLATE LIQUOR, COCOA BUTTER, PECANS,...
# 1    DEXTROSE, SUGAR, MALIC ACID, 2% OR LESS OF COR...
# 2    MADE OF: SUGAR, CORN SYRUP, HYDROGENATED PALM ...
# 3     cane sugar, unsweetened chocolate, cocoa butter.
# 4    HIGH FRUCTOSE CORN SYRUP, DISTILLED VINEGAR, T...
# ..                                                 ...
# 386                                                NaN
# 387  Evaporated Cane Sugar, Popcorn, Butter (Cream,...
# 388  SUGAR, COCOA BUTTER, HAZELNUTS, CHOCOLATE, MIL...
# 389                                                NaN
# 390                                                NaN
#
# [391 rows x 1 columns]

# %%
nutrient_breakdown_columns = ["energy-kj_value", "energy-kj_unit", "energy-kcal_value", "energy-kcal_unit", "energy-kcal_prepared_value", "energy-kcal_prepared_unit", "fat_value", "fat_unit", "fat_prepared_value", "fat_prepared_unit", "saturated-fat_value", "saturated-fat_unit", "saturated-fat_prepared_value", "saturated-fat_prepared_unit", "carbohydrates_value", "carbohydrates_unit", "carbohydrates_prepared_value", "carbohydrates_prepared_unit", "sugars_value", "sugars_unit", "sugars_prepared_value", "sugars_prepared_unit", "fiber_value", "fiber_unit", "fiber_prepared_value", "fiber_prepared_unit", "proteins_value", "proteins_unit", "proteins_prepared_value", "proteins_prepared_unit", "salt_value", "salt_unit", "salt_prepared_value", "salt_prepared_unit", "sodium_value", "sodium_unit", "sodium_prepared_value", "sodium_prepared_unit", "alcohol_value", "alcohol_unit", "energy_value", "energy_unit", "energy_prepared_value", "energy_prepared_unit", "arachidic-acid_value", "arachidic-acid_unit", "monounsaturated-fat_value", "monounsaturated-fat_unit", "polyunsaturated-fat_value", "polyunsaturated-fat_unit", "alpha-linolenic-acid_value", "alpha-linolenic-acid_unit", "arachidonic-acid_value", "arachidonic-acid_unit", "trans-fat_value", "trans-fat_unit", "trans-fat_prepared_value", "trans-fat_prepared_unit", "cholesterol_value", "cholesterol_unit", "cholesterol_prepared_value", "cholesterol_prepared_unit", "added-sugars_value", "added-sugars_unit", "added-sugars_prepared_value", "added-sugars_prepared_unit", "polyols_value", "polyols_unit", "soluble-fiber_value", "soluble-fiber_unit", "vitamin-a_value", "vitamin-a_unit", "vitamin-a_prepared_value", "vitamin-a_prepared_unit", "vitamin-d_value", "vitamin-d_unit", "vitamin-d_prepared_value", "vitamin-d_prepared_unit", "vitamin-e_value", "vitamin-e_unit", "vitamin-c_value", "vitamin-c_unit", "vitamin-b1_value", "vitamin-b1_unit", "vitamin-b2_value", "vitamin-b2_unit", "vitamin-pp_value", "vitamin-pp_unit", "vitamin-b6_value", "vitamin-b6_unit", "vitamin-b9_value", "vitamin-b9_unit", "folates_value", "folates_unit", "vitamin-b12_value", "vitamin-b12_unit", "pantothenic-acid_value", "pantothenic-acid_unit", "potassium_value", "potassium_unit", "potassium_prepared_value", "potassium_prepared_unit", "calcium_value", "calcium_unit", "calcium_prepared_value", "calcium_prepared_unit", "iron_value", "iron_unit", "iron_prepared_value", "iron_prepared_unit", "cocoa_value", "cocoa_unit"]
df[nutrient_breakdown_columns]
# Out:
#      energy-kj_value energy-kj_unit  energy-kcal_value energy-kcal_unit  \
# 0                NaN            NaN              170.0             kcal
# 1                NaN            NaN               60.0             kcal
# 2                NaN            NaN              250.0             kcal
# 3                NaN            NaN               80.0             kcal
# 4                NaN            NaN               70.0             kcal
# ..               ...            ...                ...              ...
# 386              NaN            NaN              190.0             kcal
# 387              NaN            NaN              140.0             kcal
# 388              NaN            NaN              200.0             kcal
# 389              NaN            NaN              130.0             kcal
# 390              NaN            NaN              150.0             kcal
#
#      energy-kcal_prepared_value energy-kcal_prepared_unit  fat_value fat_unit  \
# ...

# %%
packaging_columns = ["packaging_1_number_of_units", "packaging_1_shape", "packaging_1_material", "packaging_1_recycling", "packaging_1_weight_measured", "packaging_2_number_of_units", "packaging_2_shape", "packaging_2_material", "packaging_2_recycling", "packaging_3_number_of_units", "packaging_3_shape", "packaging_3_material", "packaging_3_recycling", "packaging_4_number_of_units", "packaging_4_shape", "packaging_4_material"]
df[packaging_columns]
# Out:
#      packaging_1_number_of_units packaging_1_shape packaging_1_material  \
# 0                            NaN               NaN                  NaN
# 1                            NaN        en:unknown                  NaN
# 2                            NaN               NaN                  NaN
# 3                            NaN               NaN                  NaN
# 4                            NaN               NaN                  NaN
# ..                           ...               ...                  ...
# 386                          NaN               NaN                  NaN
# 387                          NaN               NaN                  NaN
# 388                          NaN               NaN                  NaN
# 389                          NaN               NaN                  NaN
# 390                          NaN               NaN                  NaN
#
#     packaging_1_recycling  packaging_1_weight_measured  \
# ...

# %%
df[["link"]].head() # not sure what this is
# Out:
#   link
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
off_columns = ["off:food_groups", "off:food_groups_tags", "off:nova_groups", "off:nova_groups_tags", "off:nutriscore_grade", "off:nutriscore_score", "off:ecoscore_grade", "off:ecoscore_score", "off:ecoscore_data.missing_key_data", "off:ecoscore_data.agribalyse.code", "off:ecoscore_data.adjustments.origins_of_ingredients.value", "off:ecoscore_data.adjustments.packaging.value", "off:ecoscore_data.adjustments.packaging.non_recyclable_and_non_biodegradable_materials", "off:ecoscore_data.adjustments.production_system.value", "off:ecoscore_data.adjustments.threatened_species.value"]
df[off_columns]
# Out:
#              off:food_groups                        off:food_groups_tags  \
# 0      en:chocolate-products      en:sugary-snacks,en:chocolate-products
# 1                  en:sweets                  en:sugary-snacks,en:sweets
# 2                  en:sweets                  en:sugary-snacks,en:sweets
# 3      en:chocolate-products      en:sugary-snacks,en:chocolate-products
# 4    en:dressings-and-sauces  en:fats-and-sauces,en:dressings-and-sauces
# ..                       ...                                         ...
# 386                en:sweets                  en:sugary-snacks,en:sweets
# 387                      NaN                                         NaN
# 388                en:sweets                  en:sugary-snacks,en:sweets
# 389                      NaN                                         NaN
# 390                en:sweets                  en:sugary-snacks,en:sweets
#
#      off:nova_groups                          off:nova_groups_tags  \
# ...

# %%
sources_columns = ["sources_fields:org-database-usda:available_date", "sources_fields:org-database-usda:fdc_category", "sources_fields:org-database-usda:fdc_data_source", "sources_fields:org-database-usda:fdc_id", "sources_fields:org-database-usda:modified_date", "sources_fields:org-database-usda:publication_date", "data_sources"]
df[sources_columns]
# Out:
#     sources_fields:org-database-usda:available_date  \
# 0                                               NaN
# 1                              2019-01-06T00:00:00Z
# 2                                               NaN
# 3                              2019-07-17T00:00:00Z
# 4                              2018-01-31T00:00:00Z
# ..                                              ...
# 386                                             NaN
# 387                                             NaN
# 388                                             NaN
# 389                                             NaN
# 390                                             NaN
#
#     sources_fields:org-database-usda:fdc_category  \
# 0                                             NaN
# 1                                           Candy
# 2                                             NaN
# 3           Baking Decorations & Dessert Toppings
# 4            Ketchup, Mustard, BBQ & Cheese Sauce
# ...
